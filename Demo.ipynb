# %%
from attr2capt import start_decode

# %%
from IPython.display import Image
Image(filename='images/baseball.png')

# %% [markdown]
# ### Define which pre-trained model we are going to use

# %%
model_2 = '1.2'
model_5 = '1.5'
model_6_3 = '3.2'
model_6 = '1.6'

# %% [markdown]
# ### Give a input sequence and start to decode a new caption

# %%
input_attr = input('Please give a sequence of attributes to this photo: ')
start_decode(model_2, input_attr)
# Out:
# Please give a sequence of attributes to this photo: person person person person baseball bat sports
# INFO:tensorflow:Restoring parameters from ./train_data/1.1_2_3/ms_coco_model/model_2/translate.ckpt-15000
# New caption: a young girl holding a baseball bat next to his head

# %%
input_attr = input('Please give a sequence of attributes to this photo: ')
start_decode(model_5, input_attr)
# Out:
# Please give a sequence of attributes to this photo: person person person person perception listen social accompany social be_with location left distance near </s> baseball bat sports person person contact hold objects carry objects use perception touch location in_front distance full_contact distance light_contact </s> person person posture stand solo play_baseball_solo emotion neutral
# INFO:tensorflow:Restoring parameters from ./train_data/1.4_5_6/coco_a_model/model_5_500/translate.ckpt-15000
# New caption: a man in a black shirt riding on a skateboard

# %%
input_attr = input('Please give a sequence of attributes to this photo: ')
start_decode(model_6, input_attr)
# Out:
# Please give a sequence of attributes to this photo: person person person person perception listen social accompany social be_with location left distance near </s> baseball bat sports person person contact hold objects carry objects use perception touch location in_front distance full_contact distance light_contact </s> person person posture stand solo play_baseball_solo emotion neutral
# INFO:tensorflow:Restoring parameters from ./train_data/1.4_5_6/coco_a_model/model_6_500/translate.ckpt-15000
# New caption: a guy that is standing in the kitchen with a clock of a

# %%
input_attr = input('Please give a sequence of attributes to this photo: ')
start_decode(model_6, input_attr)
# Out:
# Please give a sequence of attributes to this photo: person person person person perception listen social accompany social be_with location left distance near </s> baseball bat sports person person contact hold objects carry objects use perception touch location in_front distance full_contact distance light_contact </s> person person posture stand solo play_baseball_solo emotion neutral
# INFO:tensorflow:Restoring parameters from ./train_data/1.4_5_6/coco_a_model/model_6_500/translate.ckpt-15000
#  new captions: a guy that is standing in the kitchen with a clock of a

# %%
input_attr = input('Please give a sequence of attributes to this photo: ')
start_decode(model_6, input_attr)
# Out:
# Please give a sequence of attributes to this photo: person person listen accompany be_with left near </s> baseball bat person hold carry use touch in_front full_contact light_contact </s> person stand play_baseball_solo neutral </s> person person accompany be_with left near </s> baseball bat person hold carry use touch in_front full_contact </s> person stand play_baseball_solo
# INFO:tensorflow:Restoring parameters from ./train_data/1.4_5_6/coco_a_model/model_6_500/translate.ckpt-15000
#  new captions: a man that is standing up with a bat

# %%
input_attr = input('Please give a sequence of attributes to this photo: ')
start_decode(model_6_3, input_attr)
# Out:
# Please give a sequence of attributes to this photo: erson person person person perception listen social accompany social be_with location left distance near </s> baseball bat sports person person contact hold objects carry objects use perception touch location in_front distance full_contact distance light_contact </s> person person posture stand solo play_baseball_solo emotion neutral
# INFO:tensorflow:Restoring parameters from ./train_data/3.2/coco_a_model/model_3.2/translate.ckpt-15000
# New caption: a baseball batter is getting ready to hit a ball

# %%
input_attr = input('Please give a sequence of attributes to this photo: ')
start_decode(model_2, input_attr)
# Out:
# Please give a sequence of attributes to this photo: person person person person person person
# INFO:tensorflow:Restoring parameters from ./train_data/1.1_2_3/ms_coco_model/model_2/translate.ckpt-15000
# New caption: a group of women standing on a kitchen preparing food
